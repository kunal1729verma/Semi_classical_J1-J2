# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# UNIFORM RANDOM DISTRIBUTION OF POINTS ON UNIT SPHERE.
def random_spin():
    x = np.random.normal(0, 1, 3)
    x = x/np.sqrt(x@x)
    
    return x

# RETURN THE VALUE OF SPIN MAGNITUDE.
def spin(site):
    i_ = site[0]%n
    j_ = site[1]%n
    s = spin_config[i_][j_]
    if (len(s) == 3):
        spin_val = 1
    elif (len(s) == 2):
        spin_val = 0
        
    return spin_val

# INITIALIZE ENERGY OF THE SYSTEM.
def initialize_energy():
    Energy = 0
    for i in range(n):
        for j in range(n):
            Energy += (J1/4)*(dot(spin_config[i][j], spin_config[(i+1)%n][j]) + dot(spin_config[i][j],spin_config[i][(j+1)%n]))
            Energy += (J2/4)*(dot(spin_config[i][j], spin_config[(i+1)%n][(j+1)%n]) + dot(spin_config[i][j], spin_config[(i+1)%n][(j-1)%n]))
        
    return Energy

# Calculate E
def calc_energy(spins):
    en = 0
    for i in range(n):
        for j in range(n):
            en += (J1/4)*(dot(spins[i][j], spins[(i+1)%n][j]) + dot(spins[i][j],spins[i][(j+1)%n]))
            en += (J2/4)*(dot(spins[i][j], spins[(i+1)%n][(j+1)%n]) + dot(spins[i][j], spins[(i+1)%n][(j-1)%n]))
        
    return en

# %%
# DOT PRODUCT DEFINITION

def dot(v1, v2):
    if (len(v1) == 3 and len(v2) == 3):
        dot_prod = v1@v2
    else:
        dot_prod = 0
        
    return dot_prod

# DISTANCES ON A TORUS

def dist(site1, site2):
    ix = site1[0]
    iy = site1[1]
    jx = site2[0]
    jy = site2[1]
    
    rx = abs(ix - jx)
    if (rx >= n/2):
        distancex = n - rx
    else:
        distancex = rx
        
    ry = abs(iy - jy)
    if (ry >= n/2):
        distancey = n - ry
    else:
        distancey = ry
    
    if (distancex == 0 or distancey == 0):
        distance = 1
        
    elif (distancex == 1 and distancey == 1):
        distance = 2
    
    else:
        print("Error?")
    
    return distance

# %%
def make_dimer(site):
#     print("Make")
    global E
    global spin_config

    ix = site[0]
    iy = site[1]
    
    unpaired_list = []
    for nbr in [[ix+1, iy], [ix-1, iy], [ix, iy+1], [ix, iy-1], [ix-1, iy-1], [ix-1, iy+1], [ix+1, iy-1], [ix+1, iy+1]]:
        if (spin(nbr) == 1):
            unpaired_list.append(nbr)
    
    if(len(unpaired_list)==0):
        return
    
    else:
        unpaired_indices = np.random.choice(len(unpaired_list))
        unpaired_data = unpaired_list[unpaired_indices]
        
        jx = unpaired_data[0]%n
        jy = unpaired_data[1]%n
            
        spin_config_new = np.copy(spin_config)
        
        spin_config_new[ix][iy] = [jx, jy]
        spin_config_new[jx][jy] = [ix, iy]
        
        E_old = calc_energy(spin_config)
        E_new = calc_energy(spin_config_new)
        
        dE = E_new - E_old

        # Metropolis implementation.

        p_accept = min(1, np.exp(-beta*dE))
        if (np.random.random() <= p_accept):
#             print(dE)
            spin_config[ix][iy] = [jx, jy]
            spin_config[jx][jy] = [ix, iy]
            E += dE

# %%
def spin_rotation(site):
#     print("Rotate")
    global E
    global spin_config

    ix = site[0]
    iy = site[1]
    
    spin_config_new = np.copy(spin_config)
        
    spin_config_new[ix][iy] = random_spin()
    
    E_old = calc_energy(spin_config)
    E_new = calc_energy(spin_config_new)

    dE = E_new - E_old    
    
    # Metropolis implementation.
    p_accept = min(1, np.exp(-beta*dE))
    
    if (np.random.random() <= p_accept):
#         print(dE)
        spin_config[ix][iy] = spin_config_new[ix][iy]
        E += dE

# %%
def break_dimer(site):
    print("Break")
    global E
    global spin_config

    ix = site[0]
    iy = site[1]
    
    jx = spin_config[ix][iy][0]
    jy = spin_config[ix][iy][1]
         
    spin_config_new = np.copy(spin_config)

    # Modifying a copy of the spin configutation.
    
    spin_config_new[ix][iy] = random_spin()
    spin_config_new[jx][jy] = random_spin()
    
    E_old = calc_energy(spin_config)
    E_new = calc_energy(spin_config_new)
    
    dE = E_new - E_old
    

    # Metropolis implementation.
    
    p_accept = min(1, np.exp(-beta*dE))
    if (np.random.random() <= p_accept):
#         print(dE)
        spin_config[ix][iy] = spin_config_new[ix][iy]
        spin_config[jx][jy] = spin_config_new[jx][jy]
        E += dE

# %%
# MONTE CARLO SWEEP (RANDOM)

def monte_carlo_sweep():
    
    for i in range(n*n):
        
        ix = int(np.random.random()*n)
        iy = int(np.random.random()*n)
        
        site = [ix, iy]
        
        # f tunes the ratio of random spin rotations to dimer formation. Increase f to increase dimer formation.
        f = 0.5

        # If the chosen site has a free spin.
        if (spin(site) == 1):
            if (f <= np.random.random()):
                spin_rotation(site)
            else:
                make_dimer(site)

        # If the chosen site is part of a dimer.        
        elif (spin(site) == 0):
            break_dimer(site)

    # One MC Sweep Over.
            
    free_spins = []
    
    for i in range(n):
        for j in range(n):
            if (spin([i, j]) == 1):
                free_spins.append([i, j])
    
    if(len(free_spins)==0):
        iene = E/(n*n)
        stot = np.zeros((3), dtype=np.float64)
    
        return iene, stot
    
    else:
        S = np.zeros((3), dtype=np.float64)
        
        for sites in free_spins:
            S += np.array(spin_config[sites[0]][sites[1]])*((-1)**(sites[0]+sites[1]))

    iene = E/(n*n)
    stot = S/(n*n)
    
    return iene, stot

# %%
# DEFINE THE LATTICE.
n = 10
beta = 0.02
J1 = 4
J2 = 1.5

global spin_config
spin_config = np.zeros((n, n), dtype=np.ndarray)

for i in range(n):
    for j in range(n):
        spin_config[i][j] = random_spin()
#         spin_config[i][j] = np.array([0.57735027, 0.57735027, 0.57735027])*((-1)**(i+j))
    
global E 
E = initialize_energy()

# print(spin_config, E)

nsweeps = int(5.0e4)

E_list = []
S_list = []

for i in range(nsweeps):
        E_meas, S_meas = monte_carlo_sweep()
        
        E_list.append(E_meas)
        S_list.append(S_meas)
        
        if(i%100 == 0):
            print(i)

count_dimer = 0
for i in range(n):
    for j in range(n):
        if (len(spin_config[i][j]) == 2):
            count_dimer +=1
        
print(spin_config)
print(count_dimer)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# [[array([-0.1483121 , -0.17647887,  0.97306666])
#   array([ 0.38856443, -0.17639047,  0.9043805 ]) list([9, 1])
#   array([ 0.38930458,  0.90874811, -0.15039552])
#   array([ 0.42625263, -0.76052451, -0.48980728])
#   array([0.16132288, 0.33552379, 0.92811568])
#   array([0.89939732, 0.42932426, 0.08225055])
#   array([-0.89263311,  0.04703147, -0.44832373]) list([9, 7])
#   array([ 0.87280087,  0.30447567, -0.38146193])]
#  [array([ 0.84596158,  0.51313496, -0.14505694])
#   array([-0.99033697,  0.13697795, -0.02167303])
#   array([ 0.89022667, -0.26989725,  0.36694953])
#   array([ 0.57512689, -0.25525533, -0.77722183])
#   array([ 0.92917893, -0.36956915,  0.00671973])
#   array([-0.070567  ,  0.12690592,  0.98940143]) list([1, 7])
#   list([1, 6]) array([-0.65997072,  0.75083453, -0.02619466])
#   list([2, 8])]
#  [list([2, 1]) list([2, 0]) list([3, 1])
#   array([ 0.66950153, -0.52666359, -0.52382551]) list([3, 5])
#   array([ 0.26430193, -0.86106454,  0.43441036])
#   array([ 0.30030308, -0.33664951,  0.89246018])
#   array([-0.35216028,  0.26056982,  0.89893632]) list([1, 9])
#   list([3, 9])]
#  [list([4, 9]) list([2, 2])
#   array([-0.9153979 , -0.22321728,  0.33499363])
#   array([ 0.27906939,  0.85507603, -0.43699571])
#   array([ 0.44894238, -0.48404711, -0.75109861]) list([2, 4])
#   list([4, 7]) array([ 0.39183292, -0.03435618, -0.9193947 ])
#   array([-0.28045393, -0.58383893, -0.76189087]) list([2, 9])]
#  [list([5, 0]) array([-0.45032238, -0.82646311, -0.33788827])
#   list([5, 1]) array([0.78375448, 0.4175313 , 0.45977879])
#   array([-0.47361492,  0.43261798,  0.76715748]) list([4, 6])
#   list([4, 5]) list([3, 6]) list([5, 7]) list([3, 0])]
#  [list([4, 0]) list([4, 2]) list([6, 3])
#   array([ 0.50513423, -0.84124971,  0.19271308]) list([6, 5])
#   list([5, 6]) list([5, 5]) list([4, 8]) list([6, 9])
#   array([ 0.66145953, -0.68751522,  0.29965666])]
#  [list([6, 1]) list([6, 0])
#   array([ 0.06886851, -0.02504476, -0.99731133]) list([5, 2])
#   array([-0.5829689 ,  0.49607213, -0.64347471]) list([5, 4])
#   list([7, 7]) array([ 0.44041576, -0.7762948 ,  0.45099927])
#   list([7, 9]) list([5, 8])]
#  [array([-0.76051669, -0.18988187,  0.62093417]) list([8, 0])
#   array([-0.59857667, -0.63095152, -0.49356474])
#   array([ 0.95585847, -0.15566472,  0.2492049 ])
#   array([ 0.80999762, -0.55444398, -0.19103855]) list([8, 4])
#   array([ 0.41711218, -0.85162189, -0.31742336]) list([6, 6])
#   array([ 0.59886884, -0.64410442,  0.47590504]) list([6, 8])]
#  [list([7, 1]) array([-0.06496853,  0.72563016,  0.68501093])
#   array([-0.6663095 ,  0.33223559, -0.66757109])
#   array([0.58925982, 0.65106641, 0.47841968]) list([7, 5]) list([9, 5])
#   array([ 0.20975958,  0.93196552, -0.29570456])
#   array([ 0.65831029,  0.45701666, -0.59813321])
#   array([ 0.0483364 , -0.48605777,  0.87258893]) list([9, 0])]
#  [list([8, 9]) list([0, 2])
#   array([ 0.4653647 ,  0.39041337, -0.79436333])
#   array([ 0.92846806, -0.36596728,  0.06336419])
#   array([ 0.42480565,  0.78217821, -0.4557822 ]) list([8, 5])
#   array([ 0.67742235,  0.5298761 , -0.51022572]) list([0, 8])
#   array([ 0.55071113, -0.08219085, -0.83063947])
#   array([ 0.29023172,  0.09000062, -0.95271477])]]
# 50

# %%
spin_state = np.zeros((n,n))

for i in range(n):
    for j in range(n):
        if (len(spin_config[i][j]) == 3):
            spin_state[i][j] = 1

spin_state
plt.imshow(np.array(spin_state) , cmap = 'plasma' , interpolation = 'nearest', vmin = 0, vmax = 1)
# plt.pcolormesh(np.array(spin_state), edgecolors='k', linewidth=2)
ax = plt.gca();

# Major ticks
ax.set_xticks(np.arange(0, 10, 1))
ax.set_yticks(np.arange(0, 10, 1))

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1))
ax.set_yticklabels(np.arange(1, 11, 1))

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True)
ax.set_yticks(np.arange(-.5, 10, 1), minor=True)

# Gridlines based on minor ticks
ax.grid(which='minor', color='k', linestyle='-', linewidth=2)

# Remove minor ticks
ax.tick_params(which='minor', bottom=False, left=False)
plt.show()

# %%
# Blue = Dimer
# Yellow = Free Spins

# %%
plt.plot(np.array(S_list).T[2], '.-')
plt.xlabel("Monte Carlo time")
plt.ylabel(r'$S_z/n^2$')
# plt.ylim([-1,1])
plt.grid(True)
plt.show()

# %%
plt.hist(np.array(S_list).T[2], density = True, bins = 50)
plt.xlabel(r'$S_z/n^2$')
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
plt.plot(E_list, '.-')
plt.xlabel("Monte Carlo time")
plt.ylabel(r'$E/n^2$')
plt.grid(True)
plt.show()

# %%
# DEFINE THE LATTICE.
n = 10
beta = 10
J1 = 4
J2 = 1.5

global spin_config
spin_config = np.zeros((n, n), dtype=np.ndarray)

for i in range(n):
    for j in range(n):
#         spin_config[i][j] = random_spin()
        spin_config[i][j] = np.array([0.57735027, 0.57735027, 0.57735027])*((-1)**(i+j))
    
global E 
E = calc_energy(spin_config)

# print(spin_config, E)

nsweeps = int(1.0e3)

E_list = []
S_list = []

for i in range(nsweeps):
        E_meas, S_meas = monte_carlo_sweep()
        
        E_list.append(E_meas)
        S_list.append(S_meas)
        
        if(i%100 == 0):
            print(i)

count_dimer = 0
for i in range(n):
    for j in range(n):
        if (len(spin_config[i][j]) == 2):
            count_dimer +=1
        
print(spin_config)
print(count_dimer)
# Out:
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# 0
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# ...
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Rotate
# Rotate
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Rotate
# Make
# Make
# Make
# Make
# Rotate
# Make
# Rotate
# Make
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Make
# Make
# Rotate
# Rotate
# Rotate
# Rotate
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# Make
# Make
# Make
# Rotate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10316/1142437786.py in <module>
#      24
#      25 for i in range(nsweeps):
# ---> 26         E_meas, S_meas = monte_carlo_sweep()
#      27
#      28         E_list.append(E_meas)
#
# ~\AppData\Local\Temp/ipykernel_10316/2143107354.py in monte_carlo_sweep()
#      16         if (spin(site) == 1):
#      17             if (f <= np.random.random()):
# ---> 18                 spin_rotation(site)
#      19             else:
#      20                 make_dimer(site)
#
# ~\AppData\Local\Temp/ipykernel_10316/2806803814.py in spin_rotation(site)
#       1 def spin_rotation(site):
# ----> 2     print("Rotate")
#       3     global E
#       4     global spin_config
#       5
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
plt.plot(np.array(S_list).T[2], '.-')
plt.xlabel("Monte Carlo time")
plt.ylabel(r'$S_z/n^2$')
# plt.ylim([-1,1])
plt.grid(True)
plt.show()

# %%
plt.hist(np.array(S_list).T[2], density = True, bins = 50)
plt.xlabel(r'$S_z/n^2$')
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
plt.plot(E_list, '.-')
plt.xlabel("Monte Carlo time")
plt.ylabel(r'$E/n^2$')
plt.grid(True)
plt.show()

# %%
spin_state = np.zeros((n,n))

for i in range(n):
    for j in range(n):
        if (len(spin_config[i][j]) == 3):
            spin_state[i][j] = 1

spin_state
plt.imshow(np.array(spin_state) , cmap = 'plasma' , interpolation = 'nearest', vmin = 0, vmax = 1)
# plt.pcolormesh(np.array(spin_state), edgecolors='k', linewidth=2)
ax = plt.gca();

# Major ticks
ax.set_xticks(np.arange(0, 10, 1))
ax.set_yticks(np.arange(0, 10, 1))

# Labels for major ticks
ax.set_xticklabels(np.arange(1, 11, 1))
ax.set_yticklabels(np.arange(1, 11, 1))

# Minor ticks
ax.set_xticks(np.arange(-.5, 10, 1), minor=True)
ax.set_yticks(np.arange(-.5, 10, 1), minor=True)

# Gridlines based on minor ticks
ax.grid(which='minor', color='k', linestyle='-', linewidth=2)

# Remove minor ticks
ax.tick_params(which='minor', bottom=False, left=False)
plt.show()

# %%
# Idea. Make a hybrid of naive and non-naive energetic calculations. Modify each of the "Make", "Break", "Rotate" functions one by one.
